# %% [markdown]
# # Carregando library

# %%
from google.colab import drive
drive.mount('/content/drive')
from google.colab.patches import cv2_imshow
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import numpy

# %% [markdown]
# # Esteganografia

# %%
#@title Imagens para o algortimo

escondida=cv2.imread('/content/drive/MyDrive/Colab Notebooks/PDI/img/escondida.jpg')
cv2_imshow(escondida)
print(escondida.shape)
portadora=cv2.imread('/content/drive/MyDrive/Colab Notebooks/PDI/img/portadora.jpg')
cv2_imshow(portadora)
print(portadora.shape)
#imagem que será escondida deve ter, no maximo, o tamanho da imagem portadora.
# Out:
# <PIL.Image.Image image mode=RGB size=703x460 at 0x7FB8539A9410>
# (460, 703, 3)
# <PIL.Image.Image image mode=RGB size=750x460 at 0x7FB8539A9410>
# (460, 750, 3)

# %%
print(portadora.shape[0])
print(portadora[0][0][0])
print(format(portadora[0][0][0], '08b'))
b=format(portadora[0][0][0], '08b')
print(len(format(portadora[0][0][0], '08b')))
for i in range(len(b)):
  print(b[i])
print(b[:4])
# Out:
# 460
# 164
# 10100100
# 8
# 1
# 0
# 1
# 0
# 0
# 1
# 0
# 0
# 1010

# %%
for i in range(1): 
    for j in range(1): 
        for l in range(3): 
            v1 = format(portadora[i][j][l], '08b') 
            v2 = format(escondida[i][j][l], '08b') 
            print(v1[:4], v2[4:8], v1, v2)
            v3 = v1[:4]+v2[:4] 
            print(v3, len(v3))
# Out:
# 1010 1010 10100100 10101010
# 10101010 8
# 0101 1100 01010010 10101100
# 01011010 8
# 0100 0100 01000110 10110100
# 01001011 8

# %%
for i in range(escondida.shape[0]): 
    for j in range(escondida.shape[1]): 
        for l in range(3): 
            v1 = format(portadora[i][j][l], '08b') 
            v2 = format(escondida[i][j][l], '08b') 
            v3 = v1[:6]+v2[:2]   
            portadora[i][j][l]= int(v3) 
cv2_imshow(portadora)
cv2_imshow(escondida)
# cv2.imwrite('pic3in2.png', img1)
# Out:
# <PIL.Image.Image image mode=RGB size=750x460 at 0x7FB8539361D0>
# <PIL.Image.Image image mode=RGB size=703x460 at 0x7FB855220ED0>
